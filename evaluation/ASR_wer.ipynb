# %%
import json
from jiwer import wer

def load_json(file_path):
    """Load JSON data from a file."""
    with open(file_path, 'r') as f:
        return json.load(f)

def calculate_wer(gt_json_path, pred_json_path):
    # Load the ground truth and predictions JSON files
    gt_data = load_json(gt_json_path)
    pred_data = load_json(pred_json_path)
    
    # Convert predictions to a dictionary for quick lookup by video_id
    pred_dict = {item['filename']: item['transcript'] for item in pred_data}
    
    # Initialize variables to calculate WER
    wer_scores = []
    gt_texts = []
    pred_texts = []
    
    for gt_item in gt_data:
        video_id = gt_item['video_id']
        if "subtitle" not in gt_item or len(gt_item['subtitle'])<=1:
            continue
        gt_caption = gt_item['subtitle']
        
        # Find the corresponding prediction
        pred_caption = pred_dict.get(video_id)
        
        if pred_caption:
            # Calculate WER for this pair
            error_rate = wer(gt_caption, pred_caption)
            wer_scores.append(error_rate)
            gt_texts.append(gt_caption)
            pred_texts.append(pred_caption)
        else:
            print(f"No prediction found for video ID: {video_id}")
    
    # Calculate the average WER across all pairs
    average_wer = sum(wer_scores) / len(wer_scores) if wer_scores else None
    
    return {
        "average_wer": average_wer,
        "wer_scores": wer_scores,
        "gt_texts": gt_texts,
        "pred_texts": pred_texts
    }

# Specify the paths to your GT and Prediction JSON files
gt_json_path = '../data/mix120/mix120.json'
pred_json_path = '../output/whisper_small_transcriptions.json'

# Calculate WER and print results
results = calculate_wer(gt_json_path, pred_json_path)
print("Average WER:", results["average_wer"])
for i, (gt, pred, wer_score) in enumerate(zip(results["gt_texts"], results["pred_texts"], results["wer_scores"])):
    print(f"\nPair {i + 1}:")
    print("Ground Truth:", gt)
    print("Prediction:", pred)
    print("WER:", wer_score)
# Out:
# Average WER: 0.5909673952943849
#
# Pair 1:
# Ground Truth: What Im going to have to do is I want to have to take and cut to trying to a stress relief cut in here and here on both sides.
# Prediction:  Well, what I'm gonna have to do is I'm gonna have to take and cut, try to do a stress relief cut in here, in here.
# WER: 0.5666666666666667
#
# Pair 2:
# Ground Truth: The way the game is being played, the Golden State Warriors have mastered it, theyve mastered it from the threepoint line; they mastered it from the defensive end, so they have put together a full package.
# Prediction:  way the game is being played. The Golden State Warriors have mastered it. They've mastered it from the three-point line. They've mastered it from the defensive end. So they have put together a full package
# WER: 0.3055555555555556
#
# Pair 3:
# Ground Truth: That likely means that some of the batteries were damaged, but it doesn't matter now.
# Prediction:  after a few minutes, which was all the battery power the ship had. That likely means that some of the batteries were damaged, but that doesn't matter now.
# WER: 0.9333333333333333
#
# Pair 4:
# Ground Truth: So as I look there for your belt, where you can attach the loop there off your backpack velcro, so everything fits inside of there and its stainless steel so its very durable.
# Prediction:  thing. So it has a loop there for your belt, where you can attach a loop there off your backpack. Velcro. So everything fits inside of there. And it's stainless steel.
# WER: 0.5151515151515151
#
# Pair 5:
# Ground Truth: You want to say, like hi, mom or whatever, like thats, what its like to do that right. My mom already knows Im here, good posture: yeah did you know you have good posture, so this is a little bit sort of whats going on here right, Music.
# Prediction:  you should totally join. You want to say like hi mom or whatever? Like that's what kids like to do that right? My mom already knows I'm here. Right, fair enough. Yeah, does she know you have good posture? So this is a little bit sort of what's going on here, right?
# WER: 0.5208333333333334
#
# Pair 6:
# Ground Truth: You have one meltdown and burn the city to the ground. It was gonna bring John to ashes after this.
# Prediction:  have one meltdown and burn the city to the ground. I thought Drogon was going to burn John to ashes after this. Instead he takes his wrath
# WER: 0.6
#
# Pair 7:
# Ground Truth: Thank you, maybe no one happier than Hana. So to give you an idea of just how thin this ice really is it cracks right underneath my boot now Hondas had free range of this four acres, since she was a little puppy.
# Prediction:  maybe no one happier than So to give you an idea of just really is it cracks right h
# WER: 0.5813953488372093
#
# Pair 8:
# Ground Truth: Take us away start with a thin sheet of brass were using shin stock here, 15000 scalable from McMaster.
# Prediction:  other projects, take us away. Start with a thin sheet of brass. We're using shim stock here, 15,000s, available from McMaster.
# WER: 0.5263157894736842
#
# Pair 9:
# Ground Truth: Series of looking at who will win the race to replace Dan Akerson, since he was saying Mary Barra is in the race.
# Prediction:  us to this week's series of looking at who will win the race to replace Dan Ackerson.
# WER: 0.6956521739130435
#
# Pair 10:
# Ground Truth: - Yeah. - [Jared] My philosophy was correct. - Why'd you choose to say one dad, why?
# Prediction:  My philosophy was correct! Why did you choose to stay one dad? Why?
# WER: 0.5882352941176471
#
# Pair 11:
# Ground Truth: That is to say that your watch that you do you climb a staircase you are currently courting boxing, has exactly boxing everything in body weight, its very complicated boxing skipping jump, rope, abs, pumps, its extremely complicated.
# Prediction:  Votre montre que vous fassiez vous montiez un escalier où vous fassiez de la course. Convoituellement la boxe. Exactement de la boxe. Tout ce qui est en poids de corps c'est très compliqué. Boxes, skipping, cordes à sauter, pompe, abdos, c'est extrêmement
# WER: 1.105263157894737
#
# Pair 12:
# Ground Truth: No, no, no take him a four and a half, not something I would eat all the time, but I wouldnt mind eating them again. I would definitely go out and get these again because they are really good, so I give them a shot.
# Prediction:  Not something I would eat all the time, but I wouldn't mind eating them again I would definitely go out and get these again because they are really good
# WER: 0.4444444444444444
#
# Pair 13:
# Ground Truth: Can I get your poop hey so that were at a problem, its for medical bang. Dont worry, hey everybody!
# Prediction:  It's not weird, I promise. It's for a medical thing, don't worry.
# WER: 0.9
#
# Pair 14:
# Ground Truth: What am I gonna do with this here, its an insanity. Look.
# Prediction:  baby. Look at this. What am I going to do with this hair? It's insanity. Look.
# WER: 0.75
#
# Pair 15:
# Ground Truth: Over the years, I've adapted to, basically, just a whole food type of diet, which is like this primal paleo esque type of diet, where I just eat real, good, clean food.
# Prediction:  just a whole food type of diet which is like this primal paleo-esque type of diet where I just you know eat real good clean food.
# WER: 0.46875
#
# Pair 16:
# Ground Truth: In any case, that was also very mean. It was in the afternoon ivan had already retracted nicely and was definitely really.
# Prediction:  durchgezogen. Es war auch sehr heiß. Es war nachmittags. Die Bahn war schon schön eingefahren und hat auf jeden Fall
# WER: 1.0
#
# Pair 17:
# Ground Truth: If your opponents piece blocks, either of your paths, move the rook to the occupied square and there you go, another players.
# Prediction:  If your opponent's piece blocks either of your paths, move the rook to the occupied square, and there you go!
# WER: 0.2727272727272727
#
# Pair 18:
# Ground Truth: You tell me that isnt art next were gonna, put the buns down thats wrong, but still a little more on there just for fun.
# Prediction:  is an art. Next we're gonna put the buns down. That's the wrong bun. Let's do a little
# WER: 0.88
#
# Pair 19:
# Ground Truth: You know, look like with the fiberglass wheels is very slippery.
# Prediction:  starting. Stacey Adams with the fiberglass wheels. Stacey Adams with the wheel wheels, you know, look nice. With the fiberglass wheels it's very slippery. You pump your
# WER: 1.8181818181818181
#
# Pair 20:
# Ground Truth: WATCHING. IT’S A SICKNESS. IT’S A SICKNESS. &gt;&gt; DONALD, I HOPE YOU’RE DOING  &gt;&gt; DONALD, I HOPE YOU’RE DOING OKAY. OKAY.
# Prediction:  is by for the best show. And he calls me morning psych out not even close morning
# WER: 1.0
#
# Pair 21:
# Ground Truth: Don't forget if you  haven't subscribed yet please subscribe  to my channel also give this a thumbs up  I like share or if you have something to  add remember to comment below thanks  also don't forget to stop by Tarrin Lupo  dot-com.
# Prediction:  a like, a share, or if you have something to add, remember to comment below. Thanks.
# WER: 0.7619047619047619
#
# Pair 22:
# Ground Truth: Everyone be nice to your brother. No, this is amazing.
# Prediction:  amazing it's jaw dropping right everyone be nice to your brother no this is
# WER: 0.9
#
# Pair 23:
# Ground Truth: Flashback  This Easter egg is kind of obvious, but it's still pretty awesome.
# Prediction:  I got an itch. I thought you could help me scratch cowboy. Flashback.
# WER: 1.0
#
# Pair 24:
# Ground Truth: If you paint We love one to paint all of them, dogs are already here in good hands of ourselves, so that those who arrive encourage them in this way for you, I have I think that if it is someone who needs it now, I am going to start.
# Prediction:  pintamos uno pintar todos, gracias perros, ya se quedan aquí en buenas manos los otros, para que al que llegue, se los avienten, ahí está Mándela para ustedes, chingón, pero que si se alguien que los necesita, ahora yo voy a partir de aquí porque
# WER: 1.0
#
# Pair 25:
# Ground Truth: It has risen to make a couple of losses as soon as the game begins and it has taken to light, and now we are going with the next map in the next map.
# Prediction:  Para hacer un par de bajas, nada más empezar la partida y ya se ha acabado ahí. Y ahora vamos con el siguiente mapa.
# WER: 1.0
#
# Pair 26:
# Ground Truth: My leader is all organized inside of a leader box. My worms are all organized inside of a worm.
# Prediction:  leader is all organized inside of a leader box. My worms are all organized inside of a worm bag. I've got a few plastic
# WER: 0.42105263157894735
#
# Pair 27:
# Ground Truth: Usually, simply staying away from it is enough to avoid potentially aggressive behavior. It’s fundamental never to offer food to this massive bird.
# Prediction:  Usually, simply staying away from it is enough to avoid potentially aggressive behavior. It's fundamental never to offer food to this massive bird.
# WER: 0.043478260869565216
#
# Pair 28:
# Ground Truth: The red insulation on so know where it goes first Im tempted to do is measure the battery voltage directly on this battery, its quite a big battery, its not its, not the full size in there.
# Prediction:  insulation on so I know where it goes. First thing I'm tempted to do is measure the battery voltage directly on this battery. It's quite a big battery, it's not it's not the full size in there I think
# WER: 0.3783783783783784
#
# Pair 29:
# Ground Truth: A very, very large photo and video store is like a liverpool like an iron palace, a large department store of pure photo things And video, apart from you, always find them cheaper than anywhere else.
# Prediction:  video muy muy grande es como un Liverpool como un palacio de hierro una tienda departamental grande de puras cosas de foto y video aparte de que las encuentras siempre más baratas que
# WER: 1.0
#
# Pair 30:
# Ground Truth: So this is you singing this? Is you had to get ahead to learn? I literally took me two months to learn this song phonetically it. It is so difficult.
# Prediction:  You have to learn Mandarin.
# WER: 0.9333333333333333
#
# Pair 31:
# Ground Truth: Well I? Guess that depends on how you define crying because on one hand nearly all land mammals produce tears, but these tears are used to keep their eyes moist and lubricated, so they can move easily and it helps to protect them from dirt and dust.
# Prediction:  Well, I guess that depends on how you define crying because on one hand nearly all land mammals produce tears But these tears are used to keep their eyes moist and lubricated so they can move easily and it helps to protect them from dirt
# WER: 0.1702127659574468
#
# Pair 32:
# Ground Truth: It might do a seat belt a little bit better, but its use, your blade cut your rope, and this is just kind of an afterthought, in my opinion, with the rope cutter yep.
# Prediction:  might do a seatbelt a little bit better, but it's use your blade, cut your rope, and this is just kind of an afterthought, in my opinion, with the rope cutter. Nice. Yep.
# WER: 0.2647058823529412
#
# Pair 33:
# Ground Truth: It says the matter is still getting attention. Internally, ANC campaigning continued across provinces this week and its election head wasnt boo malanga were looking forward to getting an overwhelming victory yeah in Omaha, but it will not come on its own.
# Prediction:  It says the matter is still getting attention internally. ANC campaigning continued across provinces this weekend. Its election head was in Pumalanga. We're looking forward to getting an overwhelming victory here in Pumalanga but it will not come on its own.
# WER: 0.2619047619047619
#
# Pair 34:
# Ground Truth: So Megan tell us what we know at this stage so Natasha, like you mentioned, we know that four people have been killed in this float plane crash off the coast of central BC.
# Prediction:  know at this stage. So Natasha, like you mentioned, we know that four people have been killed in this float plane crash off the coast of central BC. Five people
# WER: 0.29411764705882354
#
# Pair 35:
# Ground Truth: Oh the way, cuz, my unnatural youre, my natural eyebrow shape I can see it so I just take a little hairs that arent in the natural eyebrow and then I take off a little bits of hairs are in the center there cuz.
# Prediction:  way because my natural eyebrow shape I can see it so I just take out little hairs that aren't in the natural eyebrow and then take off little bits of hairs that are in the center
# WER: 0.3181818181818182
#
# Pair 36:
# Ground Truth: Didnt write the Harry Potter books, then I ffeel like it get rolling kind of created a loophole for herself in the Harry Potter series by making the houses match up to peoples characteristics and their creative complications.
# Prediction:  Harry Potter books then. I feel like JK Rowling kind of created a loophole for herself in the Harry Potter series by making the houses match up to people's characteristics. And this created
# WER: 0.39473684210526316
#
# Pair 37:
# Ground Truth: This first hairstyle is girly pinup, pigtails Im, wearing this vintage inspired bathing suit as a top with bright pink lips and to start off just brush out throughout your hair and the part we are going to do a diagonal and then straight down the back of your head.
# Prediction:  This first hairstyle is girly pin-up pigtails. I'm wearing this vintage inspired bathing suit as a top with bright pink lips and to start off just brush out throughout your hair and the part we are going to do a diagonal and then straight down the back of your head.
# WER: 0.06
#
# Pair 38:
# Ground Truth: It is called before entering this same lan driver. The truth is the car will be checked, then 100 according to my 60 point and it will be diagnosed and will be produced and sent actually its price will become known.
# Prediction:  ленд-ровер опруфт. Перед поступлением в этот самый ленд-ровер опруфт машина будет проверена по 100, по-моему, 60 пунктам, а диагностирована и будет произведена ее оценкой, собственно, станет известна ее цена. Дело в том,
# WER: 0.975609756097561
#
# Pair 39:
# Ground Truth: We delay my hellos yellow chakra, a genuine Shabaab. Whilst they will get her loss hobart any given stimulation to him before place.
# Prediction:  انا بوقي في الفيديو لين ما يخلص ايجاني علىكم شباب وعادة التحميل جرل بيخلص انا احبت اني جبل مخلص التحميل اشان ما تسوه من بضبط ليه سويا انا
# WER: 1.2173913043478262
#
# Pair 40:
# Ground Truth: This is exactly a hot shoe converter because it got Cornett.
# Prediction:  adapter this is exactly a hot shoe connector because it got connect
# WER: 0.36363636363636365
#
# Pair 41:
# Ground Truth: No, not really. We got the the new harleydavidson breakout, its got a 1690 cc motor uh, the what 103 B twin cam uh, and we brought along the victory gunner, which is like 160, begins like all, like all the victory yeah, so its already out gunning the Harley a little bit by three cubic.
# Prediction:  No, not really. We got the new Harley-Davidson breakout. It's got a 1690 cc motor, the 103B twin cam, and we brought along the Victory Gunner, which is like a 106 cubic inch, like all the Victory. Yeah, so it's already outgunning the Harley a little bit by three
# WER: 0.4107142857142857
#
# Pair 42:
# Ground Truth: We wish them strength during this day in the jails and we wish them a power that they know that were still with up I.
# Prediction:  them strength during their stay in the jails and we wish them power that they know that we're still with them.
# WER: 0.32
#
# Pair 43:
# Ground Truth: The reason why I do- and this is a lot of these spots right here- these are where the players are gonna- be landing so theres trying to keep these areas really nice for the players which I understand, but Ive never hit off a mat before yeah.
# Prediction:  doing this is a lot of these spots right here these are where the players are going to be landing so they're just trying to keep these areas really nice for the players which I understand but I've never hit off a mountain
# WER: 0.3333333333333333
#
# Pair 44:
# Ground Truth: So, for one of the teams that youve mentioned I think they were the ones that were able to move improve the most kind of just organically, just eternally theyre built around young players in a fair that what was a new system for them and I think they continuously got better as last season moved along and I was expecting them just to get better this year.
# Prediction:  One of the teams that you've mentioned, I think they were the ones that were able to improve the most kind of just organically, just internally. They're built around young players in a fair that what was a new system for them. And I think they continuously got better as last season moved along. And I was expecting them just to get better this year.
# WER: 0.17647058823529413
#
# Pair 45:
# Ground Truth: - So I'm just getting ready to head over to my buddy's house right now but before I left,  I actually just left, Rebecca thinks I'm gone, but I have some Pedialyte.
# Prediction:  So I'm just getting ready to head over to my buddy's house right now, but before I left I actually just left. Rebecca thinks I'm gone.
# WER: 0.3125
#
# Pair 46:
# Ground Truth: Think more of us need that in our lives like if I see like a big mountain or Im driving out in the desert and I, see a massive structure, you know its a reality.
# Prediction:  need that in our lives. Like if I see like a big mountain or I'm driving out in the desert and I see a massive structure, you know, it's a reality.
# WER: 0.2857142857142857
#
# Pair 47:
# Ground Truth: He still gets a leash, you know dragging along, but he stayed on a leash in my hand or attached to my person in the house at all time, obviously outside the house too, but in the house at all times 247, and so he I was in the kitchen.
# Prediction:  hand or attached to my person in the house at all times 24-7 and so he was in the kitchen he
# WER: 0.66
#
# Pair 48:
# Ground Truth: Youll also notice that a lot of the cages were overgrown right now now its baby season, the egg season.
# Prediction:  You'd also notice that a lot of the cages are overgrown right now. Now it's baby season, egg season.
# WER: 0.3
#
# Pair 49:
# Ground Truth: So you know that scene where M Finn is recognized by one of the stormtroopers. It goes traitor and throws his gun away and then has some handtohand gubbins going on doesnt.
# Prediction:  Well, he works. You know that scene where Finn is recognised by one of the Stormtroopers and goes, TREATER and throws his gun away and then has some hand-to-hand gubbins going on? Doesn't it
# WER: 0.4375
#
# Pair 50:
# Ground Truth: As a matter of fact, our planet has a lot of water on the inside and its quite possible that it just came from within the planet itself, but some scientists thought that maybe it came from outer space, maybe it came from comets, and so many scientists were so excited to study.
# Prediction:  As a matter of fact, our planet has a lot of water on the inside and it's quite possible that it just came from within the planet itself. But some scientists thought that maybe it came from outer space, maybe it came from comets and so many scientists were so excited to study
# WER: 0.09433962264150944
#
# Pair 51:
# Ground Truth: That way, maybe even add a little bit more warmth around there with it too. Okay, so at this point, I think were were done inside of Lightroom.
# Prediction:  adjust it that way. Maybe even add a little bit more warmth around there with it too. So at this point, I think we're done inside of Lightroom.
# WER: 0.32142857142857145
#
# Pair 52:
# Ground Truth: Voice I have never in 40 years that I attended part for me heard such a statement made, and when that time a season comes to an end.
# Prediction:  I have never in the 40 years that I have attended parts for these heard such a statement made and when that time
# WER: 0.42857142857142855
#
# Pair 53:
# Ground Truth: You just dont have the the very deep kind of conversations that we sometimes have in Germany like discussing about deep stuff of life and really sharing those loves, deep feelings that are inside of your heart.
# Prediction:  We just don't have the very deep kind of conversations that we sometimes have in Germany, like discussing about deep stuff of life and really sharing those deep feelings that are inside a
# WER: 0.21621621621621623
#
# Pair 54:
# Ground Truth: Think a heavy cream, whoo okay, I feel like a butter.
# Prediction:  That one was definitely a heavy cream. Oh good! I feel like I ate butter.
# WER: 0.8181818181818182
#
# Pair 55:
# Ground Truth: That takes place on November 23rd. For those who dont know. The procon of são paulo keeps this list that you just need to do there, a quick research to reduce the chances of having a headache when making a purchase.
# Prediction:  que acontece no próximo dia 23 de novembro. Para quem não sabe, o Proconde São Paulo mantém essa lista que você só precisa fazer lá uma rápida pesquisa para diminuir as chances de ter dor de cabeça na hora de fazer uma compra.
# WER: 1.048780487804878
#
# Pair 56:
# Ground Truth: Thank you, oh youre, on your marriage. Thank you and you guys are both. Like you know. In the zone right I know, I told her.
# Prediction:  Thank you. And you guys are both like, you know, in the zone right now.
# WER: 0.6923076923076923
#
# Pair 57:
# Ground Truth: Ill take a draw now, even though yours, you know youre trying to get that. Fourth place, I mean a. We will be massive well, it would be massive yeah thats why it would be messy and I.
# Prediction:  now. Even though you're trying to get that fourth place, a win would be massive. It would be massive. That's why it would be
# WER: 0.6842105263157895
#
# Pair 58:
# Ground Truth: What makes Smash Brothers such a big game because anywhere almost anyone can pick it up and have fun with their friends and just fight it out, and you know just like talk smack.
# Prediction:  a big game because anyone almost anyone can pick it up and have fun with their friends and just fight it out and you know
# WER: 0.3235294117647059
#
# Pair 59:
# Ground Truth: I was in the garage getting everything set up for Nicole and PJ. Nicole brought no Nicole just talking to Cole with the vet.
# Prediction:  I was in the garage getting everything set up for Nicole and PJ, Nicole Brock, no Nicole. We're just talking Nicole with a vet.
# WER: 0.2916666666666667
#
# Pair 60:
# Ground Truth: We use to be I, hope they break. You can sit like this. It work and in principle, 1234 will fit here and maybe even five little Chinese.
# Prediction:  есть стул, используем мимбочку, надеюсь она не поломается. Вы можете вот так вот сидеть и работать. И в принципе здесь поместится 1, 2, 3, 4, а может быть даже 5
# WER: 1.0714285714285714
