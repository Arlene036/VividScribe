# %% [markdown]
# # Running LLaVa-NeXT-Video: a large multi-modal model on Google Colab

# %% [markdown]
# LLaVa-NeXT-Video is a new Large Vision-Language Model that enables interaction with videos and images. The model is based on a previuos series of models: [LLaVa-NeXT](https://huggingface.co/docs/transformers/main/en/model_doc/llava_next) that was trained exclusively on image-text data. The architecutre is same as in LLaVa-NeXT and is a decoder-based text model that takes concatenated vision hidden states with text hidden states.
#
#
# <img src="http://drive.google.com/uc?export=view&id=1fVg-r5MU3NoHlTpD7_lYPEBWH9R8na_4">
#
#
# LLaVA-NeXT surprisingly has strong performance in understanding video content with the AnyRes technique that it uses. The AnyRes technique naturally represents a high-resolution image into multiple images. This technique is naturally generalizable to represent videos because videos can be considered as a set of frames (similar to a set of images in LLaVa-NeXT). The current version of LLaVA-NeXT for videos has several improvements:
#
# - LLaVA-Next-Video, with supervised fine-tuning (SFT) on top of LLaVA-Next on video data, achieves better video understanding capabilities and is a current SOTA among open-source models on [VideoMME bench](https://arxiv.org/pdf/2405.21075)
# - LLaVA-Next-Video-DPO, which aligns the model response with AI feedback using direct preference optimization (DPO), shows further performance boost.
#
# Transformers docs: https://huggingface.co/docs/transformers/main/en/model_doc/llava_next_video
# project page: https://github.com/LLaVA-VL/LLaVA-NeXT

# %% [markdown]
# First we need to install the latest `transformers` from `main`, as the model has just been added. Also we'll install `bitsandbytes` to load the model in lower bits for [memory efficiency](https://huggingface.co/blog/4bit-transformers-bitsandbytes)

# %%
# !pip install --upgrade -q accelerate bitsandbytes
# !pip install git+https://github.com/huggingface/transformers.git
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 6.6 MB/s eta 0:00:00
# Collecting git+https://github.com/huggingface/transformers.git
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-req-build-jviqyntc
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /tmp/pip-req-build-jviqyntc
#   Resolved https://github.com/huggingface/transformers.git to commit 1bd604d11c405dfb8b78bda4062d88fc75c17de0
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.46.0.dev0) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers==4.46.0.dev0) (0.24.7)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.46.0.dev0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.46.0.dev0) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.46.0.dev0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.46.0.dev0) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.46.0.dev0) (2.32.3)
# Collecting tokenizers<0.21,>=0.20 (from transformers==4.46.0.dev0)
#   Downloading tokenizers-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.46.0.dev0) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.46.0.dev0) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.46.0.dev0) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.46.0.dev0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.46.0.dev0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.46.0.dev0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.46.0.dev0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.46.0.dev0) (2024.8.30)
# Downloading tokenizers-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 37.6 MB/s eta 0:00:00
# Building wheels for collected packages: transformers
#   Building wheel for transformers (pyproject.toml) ... done
#   Created wheel for transformers: filename=transformers-4.46.0.dev0-py3-none-any.whl size=9964557 sha256=f99e5f68aa9663b445a8ba73e0fea722a711e97a33ed986d501ac6448749ce75
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7n9e_zkn/wheels/e7/9c/5b/e1a9c8007c343041e61cc484433d512ea9274272e3fcbe7c16
# Successfully built transformers
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.19.1
#     Uninstalling tokenizers-0.19.1:
#       Successfully uninstalled tokenizers-0.19.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.44.2
#     Uninstalling transformers-4.44.2:
#       Successfully uninstalled transformers-4.44.2
# Successfully installed tokenizers-0.20.0 transformers-4.46.0.dev0

# %%
# we need av to be able to read the video
# !pip install -q av
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.1/33.1 MB 11.8 MB/s eta 0:00:00

# %% [markdown]
# ## Load the model

# %% [markdown]
# Next, we load a model and corresponding processor from the hub.
#
# We will specify a quantization config to load the model in 4 bits. Please refer to this [guide](https://huggingface.co/blog/4bit-transformers-bitsandbytes) for more details.

# %%
from transformers import BitsAndBytesConfig, LlavaNextVideoForConditionalGeneration, LlavaNextVideoProcessor
import torch

quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16
)

processor = LlavaNextVideoProcessor.from_pretrained("llava-hf/LLaVA-NeXT-Video-7B-hf")
model = LlavaNextVideoForConditionalGeneration.from_pretrained(
    "llava-hf/LLaVA-NeXT-Video-7B-hf",
    quantization_config=quantization_config,
    device_map='auto'
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/741 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.36k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/43.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/552 [00:00<?, ?B/s]
# chat_template.json:   0%|          | 0.00/838 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.41k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/70.2k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.18G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]

# %% [markdown]
# ## Preparing the video and image inputs

# %% [markdown]
# In order to read the video we'll use `av` and sample 8 frames. You can try to sample more frames if the video is long. The model was trained with 32 frames, but can ingest more as long as we're in the LLM backbone's max sequence length range.

# %%
import av
import numpy as np

def read_video_pyav(container, indices):
    '''
    Decode the video with PyAV decoder.

    Args:
        container (av.container.input.InputContainer): PyAV container.
        indices (List[int]): List of frame indices to decode.

    Returns:
        np.ndarray: np array of decoded frames of shape (num_frames, height, width, 3).
    '''
    frames = []
    container.seek(0)
    start_index = indices[0]
    end_index = indices[-1]
    for i, frame in enumerate(container.decode(video=0)):
        if i > end_index:
            break
        if i >= start_index and i in indices:
            frames.append(frame)
    return np.stack([x.to_ndarray(format="rgb24") for x in frames])

# %%
# !gdown 1j3iJ1GXYcYihijDX56TodfuKWyci7wwa
# !unzip raw_video.zip
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1j3iJ1GXYcYihijDX56TodfuKWyci7wwa
# From (redirected): https://drive.google.com/uc?id=1j3iJ1GXYcYihijDX56TodfuKWyci7wwa&confirm=t&uuid=c17ee0c4-3082-4bdc-8293-99d253928865
# To: /content/raw_video.zip
# 100% 145M/145M [00:02<00:00, 69.7MB/s]
# Archive:  raw_video.zip
#    creating: raw_video/
#   inflating: raw_video/S2AfkLBFuP4.8.mp4
#   inflating: raw_video/RX5jaZv52rQ_280.000_290.000.mp4
#   inflating: raw_video/8aKhvS70_zY_40.000_50.000.mp4
#   inflating: raw_video/IauuGcFwWZg.49.mp4
#   inflating: raw_video/Uq3iKbCNDCM_60.000_70.000.mp4
#   inflating: raw_video/e6Df7Ocuqcs_180.000_190.000.mp4
#   inflating: raw_video/z3xiKSDoZEI_160.000_170.000.mp4
#   inflating: raw_video/4lUOJNaRy3I.3.mp4
#   inflating: raw_video/CgTc_-A_Gzw_0.000_8.000.mp4
#   inflating: raw_video/GfoyjUOE9Ek.8.mp4
#   inflating: raw_video/evy2azZk3kE_40.000_50.000.mp4
#   inflating: raw_video/Fn4ULUxA3KI.21.mp4
#   inflating: raw_video/QJgUEYFR49Y.46.mp4
#   inflating: raw_video/g7sVjiG-ytg_110.000_120.000.mp4
#   inflating: raw_video/_dXv_q8ierI.19.mp4
#   inflating: raw_video/D7-F3rQX4VI.4.mp4
#   inflating: raw_video/NYl0fGcNVl0.6.mp4
#   inflating: raw_video/R7ls6ZQJ5UM_570.000_580.000.mp4
#   inflating: raw_video/4KeFV0rAu_0_14.000_24.000.mp4
#   inflating: raw_video/s8UnuTvElzQ_0.000_10.000.mp4
#   inflating: raw_video/MrisGbNESmA.2.mp4
#   inflating: raw_video/BPFA7RzzJdM_10.000_20.000.mp4
#   inflating: raw_video/Bltc4o615qI.43.mp4
#   inflating: raw_video/2gc1L3g1itU_20.000_30.000.mp4
#   inflating: raw_video/TiFboW8mqd4_30.000_40.000.mp4
#   inflating: raw_video/CZc9MZIxSSc_30.000_40.000.mp4
#   inflating: raw_video/2xmCKjpuSfQ.24.mp4
#   inflating: raw_video/rzHXGinD6ZE_20.000_30.000.mp4
#   inflating: raw_video/2Tx5L5RBXxw_200.000_210.000.mp4
#   inflating: raw_video/mAG7Kwi9KOI.71.mp4
#   inflating: raw_video/Q9zKGzm4qnI.17.mp4
#   inflating: raw_video/LrL3EbvtOVw.40.mp4
#   inflating: raw_video/xfNeZaw4o3U_17.000_27.000.mp4
#   inflating: raw_video/p_o6NQX7lmE_0.000_10.000.mp4
#   inflating: raw_video/jn9rHjphwtY.3.mp4
#   inflating: raw_video/pyehK5UGPk8.17.mp4
#   inflating: raw_video/aoRW7iWXwoM.31.mp4
#   inflating: raw_video/OseeYF_ud7g_120.000_130.000.mp4
#   inflating: raw_video/wC-L0S7Lz_0.46.mp4
#   inflating: raw_video/e3BdNhbiDwA_230.000_240.000.mp4
#   inflating: raw_video/KzzKguqINa8_100.000_110.000.mp4
#   inflating: raw_video/prmGPzSpZtg.20.mp4
#   inflating: raw_video/5n0xq6pE_mg_300.000_310.000.mp4
#   inflating: raw_video/-EZDd29Id-A.21.mp4
#   inflating: raw_video/a7g3P1HGV4E_0.000_7.000.mp4
#   inflating: raw_video/aAzt7VFvhH0.5.mp4
#   inflating: raw_video/A-7BwBBtzUI.89.mp4
#   inflating: raw_video/68-QAwB8TdI.1.mp4
#   inflating: raw_video/j53tAI-EGcI_30.000_40.000.mp4
#   inflating: raw_video/Olrb-mdHJ7s_150.000_160.000.mp4
#   inflating: raw_video/sEHxWBHUAlM.121.mp4
#   inflating: raw_video/vB00cAT5iPo_60.000_70.000.mp4
#   inflating: raw_video/QPHZ8rHeIXo.8.mp4
#   inflating: raw_video/AU1l1i0H0j0_30.000_40.000.mp4
#   inflating: raw_video/0A5UYpuxRQg.10.mp4
#   inflating: raw_video/v266CJ4-yhA.12.mp4
#   inflating: raw_video/p63sYVCLVUk_30.000_40.000.mp4
#   inflating: raw_video/LOVcimphxEc.1.mp4
#   inflating: raw_video/Jy04Fe2rNmw.2.mp4
#   inflating: raw_video/wllkJ2lazaI.4.mp4
#   inflating: raw_video/P9keWnQjNJY_20.000_30.000.mp4
#   inflating: raw_video/HTBxRn8Sbyc_7.000_17.000.mp4
#   inflating: raw_video/4vtPYQ7cyd0.10.mp4
#   inflating: raw_video/5_-yllGCcFk.118.mp4
#   inflating: raw_video/zUCZ4R0NNes_0.000_10.000.mp4
#   inflating: raw_video/SlcWZ2TKjnM_140.000_150.000.mp4
#   inflating: raw_video/96VZFklUM_Q.32.mp4
#   inflating: raw_video/UbpTXBNIXtQ.18.mp4
#   inflating: raw_video/y2ZbO4KBLnY.3.mp4
#   inflating: raw_video/94Y_QnedxB8_11.000_21.000.mp4
#   inflating: raw_video/bvoF_lFC_gg.59.mp4
#   inflating: raw_video/42yFzSA1DFk_50.000_60.000.mp4
#   inflating: raw_video/eRiuGf1nzM0.3.mp4
#   inflating: raw_video/brRabaaeoy4.36.mp4
#   inflating: raw_video/zZU-PJA5Woo_30.000_40.000.mp4
#   inflating: raw_video/1lfmwRJYins.9.mp4
#   inflating: raw_video/Jk5dHnmduAg_320.000_330.000.mp4
#   inflating: raw_video/1c7NBk1x3y0_30.000_40.000.mp4
#   inflating: raw_video/clJZQsQzGCA_490.000_500.000.mp4
#   inflating: raw_video/izQ3nLG4wU0.12.mp4
#   inflating: raw_video/_PtMggNfNHY.1.mp4
#   inflating: raw_video/Sv9fcuRfk2o_70.000_80.000.mp4
#   inflating: raw_video/uLWBKxHSwyY.36.mp4
#   inflating: raw_video/-rr68KmhIzc.20.mp4
#   inflating: raw_video/ze0vbGinCyY.54.mp4
#   inflating: raw_video/CaYNuuW9rt4_11.000_21.000.mp4
#   inflating: raw_video/niJg7Q1XLyU_50.000_60.000.mp4
#   inflating: raw_video/UmWkmGAu5Hc.14.mp4
#   inflating: raw_video/uKGo4phKqLM_10.000_20.000.mp4
#   inflating: raw_video/rCqVWGlMXcY.1.mp4
#   inflating: raw_video/h8myevRe4r0_0.000_10.000.mp4
#   inflating: raw_video/INNIheBpNKY.22.mp4
#   inflating: raw_video/Wtll1g9i0M8.15.mp4
#   inflating: raw_video/b4G1my-YWoU.13.mp4
#   inflating: raw_video/9PhmPJ_p_T4.14.mp4
#   inflating: raw_video/mNsYlojC_kM_230.000_240.000.mp4
#   inflating: raw_video/YSsSpw_t0I4.45.mp4
#   inflating: raw_video/cJGg7_oC-wM_70.000_80.000.mp4
#   inflating: raw_video/6duevT5XQjI.12.mp4
#   inflating: raw_video/W7gn2todzbg_30.000_40.000.mp4
#   inflating: raw_video/Meshocn2mZQ_30.000_40.000.mp4
#   inflating: raw_video/pZF-hff52ts_60.000_70.000.mp4
#   inflating: raw_video/d3or4p2BXx0_260.000_270.000.mp4
#   inflating: raw_video/piYDsIrSvME.27.mp4
#   inflating: raw_video/7FT1WnwOcxA_40.000_50.000.mp4
#   inflating: raw_video/ockTDkyCbiY.22.mp4
#   inflating: raw_video/NAIQyoPcjNM.11.mp4
#   inflating: raw_video/ZX7EzqMBjfo_160.000_170.000.mp4
#   inflating: raw_video/uLcn-Q-TLO8.39.mp4
#   inflating: raw_video/fWwV7o4VjEQ_30.000_40.000.mp4
#   inflating: raw_video/kVDixF4dN3g.9.mp4
#   inflating: raw_video/r5kMQR8qbcQ_30.000_40.000.mp4
#   inflating: raw_video/-Vo4CAMX26U_30.000_40.000.mp4
#   inflating: raw_video/ZZKUxUjdcQw.17.mp4
#   inflating: raw_video/P2TWje4lsgQ.7.mp4
#   inflating: raw_video/Ln0Epmhtvao_150.000_160.000.mp4
#   inflating: raw_video/ZHSPLH5-zvw_50.000_60.000.mp4
#   inflating: raw_video/wj-gglKQ3KI_30.000_40.000.mp4
#   inflating: raw_video/yBYd03Hr2kQ_320.000_330.000.mp4
#   inflating: raw_video/hJYU3nBSyFo_10.000_20.000.mp4

# %%
# from huggingface_hub import hf_hub_download

# # Download video from the hub
# video_path_1 = hf_hub_download(repo_id="raushan-testing-hf/videos-test", filename="sample_demo_1.mp4", repo_type="dataset")
# video_path_2 = hf_hub_download(repo_id="raushan-testing-hf/videos-test", filename="karate.mp4", repo_type="dataset")

# container = av.open(video_path_1)

# # sample uniformly 8 frames from the video (we can sample more for longer videos)
# total_frames = container.streams.video[0].frames
# indices = np.arange(0, total_frames, total_frames / 8).astype(int)
# clip_baby = read_video_pyav(container, indices)


# container = av.open(video_path_2)

# # sample uniformly 8 frames from the video (we can sample more for longer videos)
# total_frames = container.streams.video[0].frames
# indices = np.arange(0, total_frames, total_frames / 8).astype(int)
# clip_karate = read_video_pyav(container, indices)

# %%
import os
import av
import numpy as np

def process_video(video_path, fps=4):
    container = av.open(video_path)
    video_stream = container.streams.video[0]
    video_duration = video_stream.duration * video_stream.time_base  # 获取视频时长
    original_fps = video_stream.average_rate  # 获取视频的原始帧率

    # 根据视频时长和指定的 fps 计算需要采样的帧数
    total_frames = int(video_duration * original_fps)  # 原视频的总帧数
    target_frame_count = int(video_duration * fps)  # 按照指定 fps 采样的帧数

    # 按照目标 fps 均匀采样帧
    indices = np.linspace(0, total_frames - 1, 8).astype(int)
    clip = read_video_pyav(container, indices)
    return clip

def process_all_videos_in_folder(folder_path, fps=4):
    video_clips = {}
    for filename in os.listdir(folder_path):
        if filename.endswith('.mp4'):
            video_path = os.path.join(folder_path, filename)
            print(f"Processing video: {filename}")
            clip = process_video(video_path, fps=fps)
            video_clips[filename] = clip
    return video_clips

# 假设视频文件已经下载到了指定的文件夹
folder_path = "/content/raw_video"  # 替换为你的文件夹路径
fps = 4  # 设置你想要的帧率
video_clips = process_all_videos_in_folder(folder_path, fps=fps)

# 你可以根据需要处理 video_clips 字典，里面存储了所有视频的采样帧
# Out:
# Processing video: wj-gglKQ3KI_30.000_40.000.mp4
# Processing video: 94Y_QnedxB8_11.000_21.000.mp4
# Processing video: UbpTXBNIXtQ.18.mp4
# Processing video: y2ZbO4KBLnY.3.mp4
# Processing video: Sv9fcuRfk2o_70.000_80.000.mp4
# Processing video: Ln0Epmhtvao_150.000_160.000.mp4
# Processing video: xfNeZaw4o3U_17.000_27.000.mp4
# Processing video: Meshocn2mZQ_30.000_40.000.mp4
# Processing video: TiFboW8mqd4_30.000_40.000.mp4
# Processing video: piYDsIrSvME.27.mp4
# Processing video: UmWkmGAu5Hc.14.mp4
# Processing video: uLWBKxHSwyY.36.mp4
# Processing video: p_o6NQX7lmE_0.000_10.000.mp4
# Processing video: 1lfmwRJYins.9.mp4
# Processing video: 4lUOJNaRy3I.3.mp4
# Processing video: ZZKUxUjdcQw.17.mp4
# Processing video: CZc9MZIxSSc_30.000_40.000.mp4
# Processing video: ZHSPLH5-zvw_50.000_60.000.mp4
# Processing video: brRabaaeoy4.36.mp4
# Processing video: vB00cAT5iPo_60.000_70.000.mp4
# Processing video: uLcn-Q-TLO8.39.mp4
# Processing video: HTBxRn8Sbyc_7.000_17.000.mp4
# Processing video: 7FT1WnwOcxA_40.000_50.000.mp4
# Processing video: QPHZ8rHeIXo.8.mp4
# Processing video: KzzKguqINa8_100.000_110.000.mp4
# Processing video: 96VZFklUM_Q.32.mp4
# Processing video: Q9zKGzm4qnI.17.mp4
# Processing video: LOVcimphxEc.1.mp4
# Processing video: h8myevRe4r0_0.000_10.000.mp4
# Processing video: CgTc_-A_Gzw_0.000_8.000.mp4
# Processing video: e3BdNhbiDwA_230.000_240.000.mp4
# Processing video: wC-L0S7Lz_0.46.mp4
# Processing video: 68-QAwB8TdI.1.mp4
# Processing video: -rr68KmhIzc.20.mp4
# Processing video: 4KeFV0rAu_0_14.000_24.000.mp4
# Processing video: evy2azZk3kE_40.000_50.000.mp4
# Processing video: SlcWZ2TKjnM_140.000_150.000.mp4
# Processing video: AU1l1i0H0j0_30.000_40.000.mp4
# Processing video: P9keWnQjNJY_20.000_30.000.mp4
# Processing video: Olrb-mdHJ7s_150.000_160.000.mp4
# Processing video: Bltc4o615qI.43.mp4
# Processing video: QJgUEYFR49Y.46.mp4
# Processing video: fWwV7o4VjEQ_30.000_40.000.mp4
# Processing video: mNsYlojC_kM_230.000_240.000.mp4
# Processing video: r5kMQR8qbcQ_30.000_40.000.mp4
# Processing video: A-7BwBBtzUI.89.mp4
# Processing video: g7sVjiG-ytg_110.000_120.000.mp4
# Processing video: uKGo4phKqLM_10.000_20.000.mp4
# Processing video: ockTDkyCbiY.22.mp4
# Processing video: Jk5dHnmduAg_320.000_330.000.mp4
# Processing video: 0A5UYpuxRQg.10.mp4
# Processing video: 6duevT5XQjI.12.mp4
# Processing video: prmGPzSpZtg.20.mp4
# Processing video: rzHXGinD6ZE_20.000_30.000.mp4
# Processing video: _dXv_q8ierI.19.mp4
# Processing video: yBYd03Hr2kQ_320.000_330.000.mp4
# Processing video: eRiuGf1nzM0.3.mp4
# Processing video: OseeYF_ud7g_120.000_130.000.mp4
# Processing video: BPFA7RzzJdM_10.000_20.000.mp4
# Processing video: INNIheBpNKY.22.mp4
# Processing video: D7-F3rQX4VI.4.mp4
# Processing video: sEHxWBHUAlM.121.mp4
# Processing video: MrisGbNESmA.2.mp4
# Processing video: cJGg7_oC-wM_70.000_80.000.mp4
# Processing video: 8aKhvS70_zY_40.000_50.000.mp4
# Processing video: zZU-PJA5Woo_30.000_40.000.mp4
# Processing video: CaYNuuW9rt4_11.000_21.000.mp4
# Processing video: b4G1my-YWoU.13.mp4
# Processing video: izQ3nLG4wU0.12.mp4
# Processing video: hJYU3nBSyFo_10.000_20.000.mp4
# Processing video: -EZDd29Id-A.21.mp4
# Processing video: d3or4p2BXx0_260.000_270.000.mp4
# Processing video: a7g3P1HGV4E_0.000_7.000.mp4
# Processing video: P2TWje4lsgQ.7.mp4
# Processing video: aAzt7VFvhH0.5.mp4
# Processing video: mAG7Kwi9KOI.71.mp4
# Processing video: aoRW7iWXwoM.31.mp4
# Processing video: pZF-hff52ts_60.000_70.000.mp4
# Processing video: NAIQyoPcjNM.11.mp4
# Processing video: e6Df7Ocuqcs_180.000_190.000.mp4
# Processing video: Uq3iKbCNDCM_60.000_70.000.mp4
# Processing video: _PtMggNfNHY.1.mp4
# Processing video: NYl0fGcNVl0.6.mp4
# Processing video: z3xiKSDoZEI_160.000_170.000.mp4
# Processing video: pyehK5UGPk8.17.mp4
# Processing video: clJZQsQzGCA_490.000_500.000.mp4
# Processing video: 2gc1L3g1itU_20.000_30.000.mp4
# Processing video: RX5jaZv52rQ_280.000_290.000.mp4
# Processing video: Jy04Fe2rNmw.2.mp4
# Processing video: s8UnuTvElzQ_0.000_10.000.mp4
# Processing video: ZX7EzqMBjfo_160.000_170.000.mp4
# Processing video: ze0vbGinCyY.54.mp4
# Processing video: rCqVWGlMXcY.1.mp4
# Processing video: S2AfkLBFuP4.8.mp4
# Processing video: R7ls6ZQJ5UM_570.000_580.000.mp4
# Processing video: Fn4ULUxA3KI.21.mp4
# Processing video: zUCZ4R0NNes_0.000_10.000.mp4
# Processing video: GfoyjUOE9Ek.8.mp4
# Processing video: YSsSpw_t0I4.45.mp4
# Processing video: 5n0xq6pE_mg_300.000_310.000.mp4
# Processing video: 9PhmPJ_p_T4.14.mp4
# Processing video: 4vtPYQ7cyd0.10.mp4
# Processing video: Wtll1g9i0M8.15.mp4
# Processing video: LrL3EbvtOVw.40.mp4
# Processing video: p63sYVCLVUk_30.000_40.000.mp4
# Processing video: 1c7NBk1x3y0_30.000_40.000.mp4
# Processing video: 2xmCKjpuSfQ.24.mp4
# Processing video: W7gn2todzbg_30.000_40.000.mp4
# Processing video: IauuGcFwWZg.49.mp4
# Processing video: v266CJ4-yhA.12.mp4
# Processing video: j53tAI-EGcI_30.000_40.000.mp4
# Processing video: niJg7Q1XLyU_50.000_60.000.mp4
# Processing video: -Vo4CAMX26U_30.000_40.000.mp4
# Processing video: kVDixF4dN3g.9.mp4
# Processing video: 42yFzSA1DFk_50.000_60.000.mp4
# Processing video: 2Tx5L5RBXxw_200.000_210.000.mp4
# Processing video: jn9rHjphwtY.3.mp4
# Processing video: wllkJ2lazaI.4.mp4
# Processing video: 5_-yllGCcFk.118.mp4
# Processing video: bvoF_lFC_gg.59.mp4

# %%
len(video_clips)

# %%
# sample_clip = None
# for item in video_clips.values():
#   sample_clip = item
#   break

# %%
# from matplotlib import pyplot as plt
# from matplotlib import animation
# from IPython.display import HTML

# # np array with shape (frames, height, width, channels)
# video = sample_clip

# fig = plt.figure()
# im = plt.imshow(video[0,:,:,:])

# plt.close() # this is required to not display the generated image

# def init():
#     im.set_data(video[0,:,:,:])

# def animate(i):
#     im.set_data(video[i,:,:,:])
#     return im

# anim = animation.FuncAnimation(fig, animate, init_func=init, frames=video.shape[0],
#                                interval=100)
# HTML(anim.to_html5_video())

# %% [markdown]
# ## Prepare a prompt and generate
#
# In the prompt, you can refer to video using the special `<video>` or `` token. To indicate which text comes from a human vs. the model, one uses USER and ASSISTANT respectively (note: it's true only for this checkpoint). The format looks as follows:
#
# `USER: <video>\n<prompt> ASSISTANT:`
#
#
# In other words, you always need to end your prompt with ASSISTANT:.
#
#
# Manually adding USER and ASSISTANT to your prompt can be error-prone since each checkpoint has its own prompt format expected, depending on the backbone language model. Luckily we can use `apply_chat_template` to make it easier.
#
# Chat templates are special templates written in jinja and added to the model's config. Whenever we call `apply_chat_template`, the jinja template in filled in with your text instruction.
#
# To use chat template simply build a list of messages, with role and content keys, and then pass it to the `apply_chat_template()` method. Once you do that, you’ll get output that’s ready to go! When using chat templates as input for model generation, it’s also a good idea to use `add_generation_prompt=True` to add a generation prompt. See [the docs](https://huggingface.co/docs/transformers/main/en/chat_templating) for more details

# %%
import json
with open('/content/unimodal_whisper_small_audiocap.json', 'r') as f:
  audio_cap = json.load(f)

# %%
audio_cap = audio_cap['annotations']

# %%
type(video_clips)

# %%
# Each "content" is a list of dicts and you can add image/video/text modalities
def set_prompt(audio_caption):
    PROMPT = f"""
    Given the video and the audio captioning of this video, describe this video.
    Audio captioning is as follows:
    {audio_caption}
    """

    conversation = [
          {
              "role": "user",
              "content": [
                  {"type": "text", "text": PROMPT},
                  {"type": "video"},
                  ],
          },
    ]

    prompt = processor.apply_chat_template(conversation, add_generation_prompt=True)
    return prompt

# %%
audio_cap_dict = {item['video_id']: item['caption'] for item in audio_cap}

# %%
SKIPPED_IDS = [
    "p_o6NQX7lmE_0.000_10.000.mp4",
    "xJ-6ewqMyxY_410.000_420.000.mp4",
    "niJg7Q1XLyU_50.000_60.000.mp4",
    "wj-gglKQ3KI_30.000_40.000.mp4"]

# %%
# iterate with video_clips
generate_kwargs = {"max_new_tokens": 100, "do_sample": True, "top_p": 0.9}
output_file = '/content/multimodal_llava-whisper-generation.json'
# make dir
os.makedirs(os.path.dirname(output_file), exist_ok=True)

# get exists video name
exits_video = []
import json

file_path = output_file
with open(file_path, 'r') as file:
    lines = file.readlines()

video_names = []
for line in lines:
    data = json.loads(line)
    video_name = data.get("video_name", "")
    video_names.append(video_name)

# 打印提取出的 video_name
for name in video_names:
    exits_video.append(name+'.mp4')

# %%
for video_name, video_clip in video_clips.items():
  if video_name in SKIPPED_IDS or video_name in exits_video:
    continue
  video_name = video_name.split('.mp4')[0]
  prompt = set_prompt(audio_cap_dict[video_name])
  # we need to call the processor to tokenize the prompt and get pixel_values for videos
  inputs = processor([prompt], videos=[video_clip], padding=True, return_tensors="pt").to(model.device)
  output = model.generate(**inputs, **generate_kwargs)
  generated_text = processor.batch_decode(output, skip_special_tokens=True)
  # append to the json file
  with open(output_file, 'a') as f:
    f.write(json.dumps({'video_name': video_name, 'generated_text': generated_text[0].split('ASSISTANT: ')[-1]}) + '\n')

# %%
import json

# Input file path
input_file = '/content/multimodal_llava-whisper-generation.json'  # Replace with your actual file path
output_file = '/content/multimodal_llava-whisper-ac.json'  # Output file path

annotations = []

# Read the input file line by line
with open(input_file, 'r') as f:
    for line in f:
        # Parse each line as JSON
        data = json.loads(line.strip())

        # Create a new dictionary with the desired format
        annotations.append({
            "video_id": data["video_name"],
            "caption": data["generated_text"].strip()
        })

# Create the final output structure
output_data = {
    "annotations": annotations
}

# Write the formatted output to a JSON file
with open(output_file, 'w') as f:
    json.dump(output_data, f, indent=4)

print(f"Formatted output saved to {output_file}")
# Out:
# Formatted output saved to /content/multimodal_llava-whisper-ac.json
